# %% [markdown]
# # Homeless
# Inteligencia Artificial - Facundo A. Lucianna - CEIA - FIUBA
#
# Para este trabajo, se incorpora un csv (*homeless2021.csv*) con información de estimaciones de falta de vivienda en los estados de EE UU en 2021. Se presenta para 6 columnas, 3 con información de cuantos el número de vagabundos individuales (*individuals*) que no forman parte de una familia, y otra 3 con el número de vagabundos que son parte de una familia con hijos (*family*). Son tres para cada una, correspondiendo a la separación por género (masculino y femenino) y una sin discriminar el género. Además, *state_pop* presenta el total de la población del estado.
#
# La información la obtuvimos de [endhomelessness.org](https://endhomelessness.org/homelessness-in-america/homelessness-statistics/state-of-homelessness-2021/)
#
# OBS: En las celdas de procesamiento si ves ___ es para que reemplaces.
#
# ----
# ## Primeros pasos exploratorios
#
# Una de las primeras cosas que podemos hacer cuando tenemos un DataFrame nuevo, es explorarlo y ver que contiene. Entre las herramientas de Pandas que nos permite hacer eso son:
#
# - `.head()`
# - `.info()`
# - `.shape`
# - `.describe()`
#
# Por lo que pongamos manos a la obra:
#
# 1. Importa `pandas` como `pd`

# %%
import pandas as pd

# %% [markdown]
# 2. Lea el csv en un DataFrame y llame al DataFrame `homeless`

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\60080956

# %%
homeless = pd.read_csv(r"C:\Users\60080956\Documents\CEIA\intro_ia\clase1\ejercicios\datasets\homeless2021.csv")

# %% [markdown]
# 3. Muestre la cabecera del DataFrame con las primeras 7 filas.

# %%
homeless.head(7)
# Out:
#                region        state state code  individuals  individuals male  \
# 0             Pacific       Alaska         AK         1295               981
# 1  East South Central      Alabama         AL         1165               782
# 2  West South Central     Arkansas         AR         1204               800
# 3            Mountain      Arizona         AZ         3304              2234
# 4             Pacific   California         CA        32910             21041
# 5            Mountain     Colorado         CO         5569              3954
# 6         New England  Connecticut         CT         1504              1078
#
#    individuals female  family_members  family_members male  \
# 0                 310             502                  190
# 1                 377             461                  172
# 2                 403             266                   98
# 3                1046            2156                  840
# 4               11434           18519                 7495
# 5                1587            2447                  960
# 6                 418             661                  218
#
#    family_members female  pop_state
# 0                    312     735707
# 1                    289    5048733
# 2                    168    3021085
# 3                   1313    7227450
# 4                  11009   39766650
# 5                   1482    5848166
# 6                    442    3609129

# %% [markdown]
# 4. Muestre información sobre los tipos de columna y los valores faltantes

# %%
homeless.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   region                 50 non-null     object
#  1   state                  50 non-null     object
#  2   state code             50 non-null     object
#  3   individuals            50 non-null     int64
#  4   individuals male       50 non-null     int64
#  5   individuals female     50 non-null     int64
#  6   family_members         50 non-null     int64
#  7   family_members male    50 non-null     int64
#  8   family_members female  50 non-null     int64
#  9   pop_state              50 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 4.0+ KB

# %%
homeless.describe()
# Out:
#         individuals  individuals male  individuals female  family_members  \
# count     50.000000         50.000000           50.000000       50.000000
# mean    3822.180000       2584.640000         1202.880000     2597.660000
# std     6803.230984       4602.243081         2132.664087     5920.848076
# min      247.000000        108.000000           92.000000       88.000000
# 25%     1153.750000        779.000000          352.500000      491.500000
# 50%     1833.000000       1154.500000          639.500000      775.000000
# 75%     3755.000000       2536.000000         1256.750000     2374.250000
# max    37793.000000      26504.000000        11434.000000    38258.000000
#
#        family_members male  family_members female     pop_state
# count            50.000000              50.000000  5.000000e+01
# mean           1007.200000            1587.140000  6.660427e+06
# std            2329.894742            3590.597841  7.496315e+06
# min              27.000000              61.000000  5.781730e+05
# 25%             184.750000             302.250000  1.893448e+06
# 50%             324.500000             470.000000  4.596339e+06
# 75%             930.000000            1452.250000  7.659379e+06
# max           14958.000000           23294.000000  3.976665e+07

# %% [markdown]
# 5. Muestre la cantidad de filas y columnas que posee el DataFrame.

# %%
import numpy as np
homeless.shape
# Out:
# (50, 10)

# %% [markdown]
# 6. Imprima algunas estadísticas resumidas del DataFrame.

# %%
homeless.describe()
# Out:
#         individuals  individuals male  individuals female  family_members  \
# count     50.000000         50.000000           50.000000       50.000000
# mean    3822.180000       2584.640000         1202.880000     2597.660000
# std     6803.230984       4602.243081         2132.664087     5920.848076
# min      247.000000        108.000000           92.000000       88.000000
# 25%     1153.750000        779.000000          352.500000      491.500000
# 50%     1833.000000       1154.500000          639.500000      775.000000
# 75%     3755.000000       2536.000000         1256.750000     2374.250000
# max    37793.000000      26504.000000        11434.000000    38258.000000
#
#        family_members male  family_members female     pop_state
# count            50.000000              50.000000  5.000000e+01
# mean           1007.200000            1587.140000  6.660427e+06
# std            2329.894742            3590.597841  7.496315e+06
# min              27.000000              61.000000  5.781730e+05
# 25%             184.750000             302.250000  1.893448e+06
# 50%             324.500000             470.000000  4.596339e+06
# 75%             930.000000            1452.250000  7.659379e+06
# max           14958.000000           23294.000000  3.976665e+07

# %% [markdown]
# Siguiendo explorando nuestro DataFrame, es útil saber siempre que sea posible, analizar las columnas, índices y elementos de nuestro DataFrame. Para ello tenemos tres atributos:
#
# - `.values`: Nos devuelve un array de Numpy de dos dimensiones con los valores.
# - `.columns`: Un índice de columnas con los nombres de las columnas.
# - `.index`: Un índice de filas, ya sea números de fila o nombres de fila.
#
# Siguiendo con el mismo DataFrame del punto anterior (`homeless`):
#
# 1. Imprima una matriz Numpy con los valores de `homeless`

# %%
homeless.values
# Out:
# array([['Pacific', 'Alaska', 'AK', 1295, 981, 310, 502, 190, 312, 735707],
#        ['East South Central', 'Alabama', 'AL', 1165, 782, 377, 461, 172,
#         289, 5048733],
#        ['West South Central', 'Arkansas', 'AR', 1204, 800, 403, 266, 98,
#         168, 3021085],
#        ['Mountain', 'Arizona', 'AZ', 3304, 2234, 1046, 2156, 840, 1313,
#         7227450],
#        ['Pacific', 'California', 'CA', 32910, 21041, 11434, 18519, 7495,
#         11009, 39766650],
#        ['Mountain', 'Colorado', 'CO', 5569, 3954, 1587, 2447, 960, 1482,
#         5848166],
#        ['New England', 'Connecticut', 'CT', 1504, 1078, 418, 661, 218,
#         442, 3609129],
#        ['South Atlantic', 'Delaware', 'DE', 736, 477, 257, 843, 340, 503,
#         999149],
#        ['South Atlantic', 'Florida', 'FL', 8412, 6001, 2355, 4981, 1774,
#         3207, 21811875],
#        ['South Atlantic', 'Georgia', 'GA', 3111, 2191, 894, 2121, 669,
#         1363, 10814334],
#        ['Pacific', 'Hawaii', 'HI', 1142, 703, 429, 1348, 625, 719,
#         1464768],
#        ['West North Central', 'Iowa', 'IA', 1321, 906, 412, 685, 257,
#         428, 3204770],
#        ['Mountain', 'Idaho', 'ID', 591, 370, 219, 426, 160, 265, 1866258],
#        ['East North Central', 'Illinois', 'IL', 4065, 2632, 1402, 2868,
#         1060, 1808, 12810696],
#        ['East North Central', 'Indiana', 'IN', 2765, 1961, 793, 1285,
#         471, 812, 6815701],
#        ['West North Central', 'Kansas', 'KS', 1113, 759, 348, 487, 194,
#         292, 2946356],
#        ['East South Central', 'Kentucky', 'KY', 1704, 1140, 558, 583,
#         202, 381, 4522483],
#        ['West South Central', 'Louisiana', 'LA', 1150, 830, 312, 463,
#         168, 295, 4670195],
#        ['New England', 'Massachusetts', 'MA', 4278, 2908, 1335, 9666,
#         3806, 5858, 7078146],
#        ['South Atlantic', 'Maryland', 'MD', 2764, 1938, 812, 1284, 470,
#         813, 6217591],
#        ['New England', 'Maine', 'ME', 1278, 779, 487, 785, 320, 465,
#         1365759],
#        ['East North Central', 'Michigan', 'MI', 3768, 2562, 1184, 2778,
#         1063, 1715, 10096700],
#        ['West North Central', 'Minnesota', 'MN', 3716, 2400, 1281, 2745,
#         1049, 1691, 5746751],
#        ['West North Central', 'Missouri', 'MO', 2359, 1419, 918, 1720,
#         650, 1070, 6171512],
#        ['East South Central', 'Mississippi', 'MS', 271, 159, 110, 88, 27,
#         61, 2960677],
#        ['Mountain', 'Montana', 'MT', 744, 511, 230, 424, 167, 257,
#         1093706],
#        ['South Atlantic', 'North Carolina', 'NC', 3609, 2458, 1140, 2003,
#         774, 1229, 10529778],
#        ['West North Central', 'North Dakota', 'ND', 290, 196, 92, 184,
#         64, 120, 789744],
#        ['West North Central', 'Nebraska', 'NE', 1280, 908, 366, 496, 196,
#         299, 1975020],
#        ['New England', 'New Hampshire', 'NH', 649, 434, 214, 522, 201,
#         321, 1383635],
#        ['Mid-Atlantic', 'New Jersey', 'NJ', 4821, 3319, 1489, 2622, 968,
#         1653, 9338704],
#        ['Mountain', 'New Mexico', 'NM', 1217, 779, 420, 755, 329, 425,
#         2123356],
#        ['Mountain', 'Nevada', 'NV', 2748, 2034, 691, 545, 183, 361,
#         3145020],
#        ['Mid-Atlantic', 'New York', 'NY', 37793, 26504, 10819, 38258,
#         14958, 23294, 20283564],
#        ['East North Central', 'Ohio', 'OH', 5020, 3408, 1586, 2742, 1026,
#         1714, 11825742],
#        ['West South Central', 'Oklahoma', 'OK', 1674, 1073, 588, 657,
#         263, 394, 3980153],
#        ['Pacific', 'Oregon', 'OR', 4167, 2764, 1338, 1011, 415, 592,
#         4277874],
#        ['Mid-Atlantic', 'Pennsylvania', 'PA', 5450, 3772, 1645, 3914,
#         1455, 2454, 13032732],
#        ['New England', 'Rhode Island', 'RI', 614, 440, 170, 472, 176,
#         295, 1101860],
#        ['South Atlantic', 'South Carolina', 'SC', 1552, 1154, 397, 490,
#         163, 327, 5167731],
#        ['West North Central', 'South Dakota', 'SD', 517, 353, 161, 300,
#         105, 195, 893916],
#        ['East South Central', 'Tennessee', 'TN', 2678, 1885, 784, 765,
#         290, 475, 6967314],
#        ['West South Central', 'Texas', 'TX', 7518, 5017, 2460, 3757,
#         1421, 2335, 29545499],
#        ['Mountain', 'Utah', 'UT', 1664, 1072, 576, 746, 285, 459,
#         3322389],
#        ['South Atlantic', 'Virginia', 'VA', 3430, 2327, 1083, 1905, 746,
#         1158, 8694430],
#        ['New England', 'Vermont', 'VT', 1962, 1155, 793, 629, 255, 374,
#         644811],
#        ['Pacific', 'Washington', 'WA', 7013, 4594, 2310, 4498, 1842,
#         2647, 7803355],
#        ['East North Central', 'Wisconsin', 'WI', 2275, 1534, 723, 1721,
#         683, 1036, 5914391],
#        ['South Atlantic', 'West Virginia', 'WV', 682, 428, 250, 141, 60,
#         81, 1787788],
#        ['Mountain', 'Wyoming', 'WY', 247, 108, 138, 158, 57, 101, 578173]],
#       dtype=object)

# %% [markdown]
# 2. Imprima los nombres de la columna de `homeless`

# %%
homeless.columns
# Out:
# Index(['region', 'state', 'state code', 'individuals', 'individuals male',
#        'individuals female', 'family_members', 'family_members male',
#        'family_members female', 'pop_state'],
#       dtype='object')

# %% [markdown]
# 3. Imprima el índice de `homeless`

# %%
homeless.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# ---
#
# ## Ordenando valores
#
# Una forma rápida de encontrar pedazos de datos interesantes en un DataFrame es reordenando el orden de las filas. En un DataFrame, se puede ordenar usando `.sort_values()`. En los casos en que las filas tengan el mismo valor, es posible que desee ordenar en más de una columna. Puede ordenar varias columnas de esta manera pasando una lista de nombres de columnas.
#
# | Ordenar usando... | Sintaxis  |
# |---|---|
# | una columna.   | `df.sort_values("sexo")`   |
# | múltiples columnas.  | `df.sort_values(["sexo", "peso"])`  |
#
# `.sort_values()` por defecto ordena de menor a mayor (ascendente), pero es posible cambiarlo para que sea descendente, usando el parámetro opcional `ascending=False`.
#
# | Ordenar... | Sintaxis  |
# |---|---|
# | de menor a mayor.   | `df.sort_values("sexo")`   |
# | de mayor a menor.  | `df.sort_values("sexo", ascending=False)`  |
# | con múltiples columnas.  | `df.sort_values(["sexo", "peso"], ascending=[False, True])`  |
#
# Al combinar `.sort_values()` con `.head()`, podés responder preguntas del tipo "¿Cuáles son los casos principales donde...?".
#
# Siguiendo con el mismo DataFrame del punto anterior (`homeless`):
#
# 1. Ordene `homeless` por el número de personas sin hogar inviduales (`individuals`), de menor a mayor, y guárdelo como `homelessness_ind`.

# %%
homeless_ind = homeless.sort_values(by='individuals', ascending=True)

# %% [markdown]
# 2. Imprima el encabezado del DataFrame ordenado.

# %%
homeless_ind.head()
# Out:
#                 region         state state code  individuals  \
# 49            Mountain       Wyoming         WY          247
# 24  East South Central   Mississippi         MS          271
# 27  West North Central  North Dakota         ND          290
# 40  West North Central  South Dakota         SD          517
# 12            Mountain         Idaho         ID          591
#
#     individuals male  individuals female  family_members  family_members male  \
# 49               108                 138             158                   57
# 24               159                 110              88                   27
# 27               196                  92             184                   64
# 40               353                 161             300                  105
# 12               370                 219             426                  160
#
#     family_members female  pop_state
# 49                    101     578173
# 24                     61    2960677
# 27                    120     789744
# 40                    195     893916
# 12                    265    1866258

# %% [markdown]
# 3. Ordene `homeless` por el número de personas sin hogar con familias (`family_members`), de mayor a menor, y guárdelo como `homelessness_fam`.

# %%
homeless_fam = homeless.sort_values(by='family_members', ascending=False)

# %% [markdown]
# 4. Imprima el encabezado del DataFrame ordenado.

# %%
homeless_fam.head()
# Out:
#             region          state state code  individuals  individuals male  \
# 33    Mid-Atlantic       New York         NY        37793             26504
# 4          Pacific     California         CA        32910             21041
# 18     New England  Massachusetts         MA         4278              2908
# 8   South Atlantic        Florida         FL         8412              6001
# 46         Pacific     Washington         WA         7013              4594
#
#     individuals female  family_members  family_members male  \
# 33               10819           38258                14958
# 4                11434           18519                 7495
# 18                1335            9666                 3806
# 8                 2355            4981                 1774
# 46                2310            4498                 1842
#
#     family_members female  pop_state
# 33                  23294   20283564
# 4                   11009   39766650
# 18                   5858    7078146
# 8                    3207   21811875
# 46                   2647    7803355

# %% [markdown]
# Responda con estos puntos:
#
# 1. ¿Qué estado posee menos personas sin hogar inviduales?
# 2. ¿Cuál es el tercer  estado con más personas sin hogar con familias?
#
# ---
#
# ## Slicing de columnas
#
# Cuando trabaja con un dataset, es posible que no se necesiten todas las columnas. Los corchetes ([]) se pueden usar para seleccionar solo las columnas que interesan, además en un orden que tenga sentido. Para seleccionar solamente la columna `"col_a"` del DataFrame `df`, se debe usar:
#
# ``` Python
# df["col_a"]
# ```
#
# Para seleccionar `"col_a"` y `"col_b"` de `df`, usar
#
# ``` Python
# df[["col_a", "col_b"]]
# ```
#
# Obsérvese, que si se cambia el orden de  `"col_a"` y `"col_b"` , el DataFrame va a mostrar las columnas en ese orden.
#
# Siguiendo con el mismo DataFrame del punto anterior (`homeless`):
#
# 1. Cree un DataFrame llamado `individuals` que contiene solo la columna de `homeless` asociada a la medición de vagabundo inviduales sin discriminar genero (`individuals`).

# %%
individuals = homeless[["individuals"]]

# %% [markdown]
# 2. Muestre la cabecera del resultado.

# %%
individuals.head()
# Out:
#    individuals
# 0         1295
# 1         1165
# 2         1204
# 3         3304
# 4        32910

# %% [markdown]
# 3. Cree un DataFrame llamado `state_fam` que contiene solo las columnas de `homeless`  con el nombre de estado (`state`) y el número de vagabundo con familia sin discriminar género (`family_members`).

# %%
state_fam = homeless[["state", "family_members"]]

# %% [markdown]
# 4. Muestre la cabecera del resultado.

# %%
state_fam.head()
# Out:
#         state  family_members
# 0      Alaska             502
# 1     Alabama             461
# 2    Arkansas             266
# 3     Arizona            2156
# 4  California           18519

# %% [markdown]
# 5. Cree un DataFrame llamado `ind_state_by_sex` que contenga a los estados (`state`), el número de vagabundos individuales que se identifican como mujer (`individuals female`)  y el número de vagabundos individuales que se identifican como hombres (`individuals male`). En ese orden.

# %%
ind_state_by_sex = homeless[["state", "individuals female", "individuals male"]]

# %% [markdown]
# 6. Muestre la cabecera del resultado.

# %%
ind_state_by_sex.head()
# Out:
#         state  individuals female  individuals male
# 0      Alaska                 310               981
# 1     Alabama                 377               782
# 2    Arkansas                 403               800
# 3     Arizona                1046              2234
# 4  California               11434             21041

# %% [markdown]
# ---
#
# ## Filtros avanzados
#
# Una gran parte del trabajo en ciencias de datos es encontrar que partes de tu dataset son interesantes. Una de las técnicas más simples para esto es encontrar un subconjunto de filas que coincidan con algunos criterios.
#
# Hay muchas maneras de crear subconjuntos de un DataFrame, quizás la más común, tal como vimos en clase, es usar operadores relacionales para devolver `True` o `False` para cada fila, luego pasar eso entre corchetes:
#
# ``` Python
# df[df["sexo" == "Female"]]
# df[df["peso" > 80]]
# ```
#
# Recordar también que se puede filtrar combinando los filtros con operadores bitwise:
#
# ``` Python
# df[(df["sexo" == "Female"]) & (df["peso" > 80])]
# ```
#
# Siguiendo con el mismo DataFrame de los puntos anteriores (`homeless`):
#
# 1. Filtre  `homeless` para los estados (`state`) en donde posee el numero número de vagabundos individuales (`individuals`) sea mayor a 5000, guardándolo en `ind_gt_5k`. Y muestre el resultado.

# %%
ind_gt_5k = homeless[homeless["individuals"] > 5000]

ind_gt_5k
# Out:
#                 region         state state code  individuals  \
# 4              Pacific    California         CA        32910
# 5             Mountain      Colorado         CO         5569
# 8       South Atlantic       Florida         FL         8412
# 33        Mid-Atlantic      New York         NY        37793
# 34  East North Central          Ohio         OH         5020
# 37        Mid-Atlantic  Pennsylvania         PA         5450
# 42  West South Central         Texas         TX         7518
# 46             Pacific    Washington         WA         7013
#
#     individuals male  individuals female  family_members  family_members male  \
# 4              21041               11434           18519                 7495
# 5               3954                1587            2447                  960
# 8               6001                2355            4981                 1774
# 33             26504               10819           38258                14958
# 34              3408                1586            2742                 1026
# 37              3772                1645            3914                 1455
# 42              5017                2460            3757                 1421
# 46              4594                2310            4498                 1842
#
#     family_members female  pop_state
# 4                   11009   39766650
# 5                    1482    5848166
# 8                    3207   21811875
# 33                  23294   20283564
# 34                   1714   11825742
# 37                   2454   13032732
# 42                   2335   29545499
# 46                   2647    7803355

# %% [markdown]
# 2. Filtre `homeless` en donde las región es `"Mountain"`, guardándolo en `mountain_reg`. Muestre el resultado.

# %%
mountain_reg = homeless[homeless["region"] == "Mountain"]
mountain_reg
# Out:
#       region       state state code  individuals  individuals male  \
# 3   Mountain     Arizona         AZ         3304              2234
# 5   Mountain    Colorado         CO         5569              3954
# 12  Mountain       Idaho         ID          591               370
# 25  Mountain     Montana         MT          744               511
# 31  Mountain  New Mexico         NM         1217               779
# 32  Mountain      Nevada         NV         2748              2034
# 43  Mountain        Utah         UT         1664              1072
# 49  Mountain     Wyoming         WY          247               108
#
#     individuals female  family_members  family_members male  \
# 3                 1046            2156                  840
# 5                 1587            2447                  960
# 12                 219             426                  160
# 25                 230             424                  167
# 31                 420             755                  329
# 32                 691             545                  183
# 43                 576             746                  285
# 49                 138             158                   57
#
#     family_members female  pop_state
# 3                    1313    7227450
# 5                    1482    5848166
# 12                    265    1866258
# 25                    257    1093706
# 31                    425    2123356
# 32                    361    3145020
# 43                    459    3322389
# 49                    101     578173

# %% [markdown]
# 3. Filtre `homeless` para los estados en donde el número de personas sin hogar con familias se menor o igual a 1000 y que la región sea `“Pacific”`, asignelo a `fam_lt_1k_pac`. Muestre el resultado.

# %%
fam_lt_1k_pac = homeless[(homeless["region"] == "Pacific") & (homeless["family_members"] < 1000)]
fam_lt_1k_pac
# Out:
#     region   state state code  individuals  individuals male  \
# 0  Pacific  Alaska         AK         1295               981
#
#    individuals female  family_members  family_members male  \
# 0                 310             502                  190
#
#    family_members female  pop_state
# 0                    312     735707

# %% [markdown]
# ---
#
# ## Filtros más avanzados
#
# La creación de un subconjunto de datos basados en una variable categórica, en general implica utilizar el operador “or” (`|`) para seleccionar filas de varias categorias. Por ejemplo,
#
# ``` Python
# df[(df["estado" == "soltero"]) | (df["estado" == "divorciado"])]
# ```
#
# Esto puede volverse tedioso cuando se quiere filtrar multiples valores. En su lugar, se puede utilizar el método `.isin()`, que permite abordar este problema escribiendo una condición en lugar de tres separadas.
#
# ``` Python
# estados_filtrados = ["soltero", "divorciado"]
# condition = df["estado"].isin(estados_filtrados)
# df[condition]
# ```
#
# Siguiendo con el mismo DataFrame de los puntos anteriores (`homeless`):
#
# 1. Filtre  `homeless` para los casos en que la región es `"South Atlantic"` o es `"Mid-Atlantic"`, asignelo a `south_mid_atlantic`. Muestre el resultado.

# %%
south_mid_atlantic = homeless[homeless["region"].isin(["South Atlantic", "Mid-Atlantic"])]
south_mid_atlantic
# Out:
#             region           state state code  individuals  individuals male  \
# 7   South Atlantic        Delaware         DE          736               477
# 8   South Atlantic         Florida         FL         8412              6001
# 9   South Atlantic         Georgia         GA         3111              2191
# 19  South Atlantic        Maryland         MD         2764              1938
# 26  South Atlantic  North Carolina         NC         3609              2458
# 30    Mid-Atlantic      New Jersey         NJ         4821              3319
# 33    Mid-Atlantic        New York         NY        37793             26504
# 37    Mid-Atlantic    Pennsylvania         PA         5450              3772
# 39  South Atlantic  South Carolina         SC         1552              1154
# 44  South Atlantic        Virginia         VA         3430              2327
# 48  South Atlantic   West Virginia         WV          682               428
#
#     individuals female  family_members  family_members male  \
# 7                  257             843                  340
# 8                 2355            4981                 1774
# 9                  894            2121                  669
# 19                 812            1284                  470
# 26                1140            2003                  774
# 30                1489            2622                  968
# 33               10819           38258                14958
# 37                1645            3914                 1455
# 39                 397             490                  163
# 44                1083            1905                  746
# 48                 250             141                   60
#
#     family_members female  pop_state
# 7                     503     999149
# 8                    3207   21811875
# 9                    1363   10814334
# 19                    813    6217591
# 26                   1229   10529778
# 30                   1653    9338704
# 33                  23294   20283564
# 37                   2454   13032732
# 39                    327    5167731
# 44                   1158    8694430
# 48                     81    1787788

# %% [markdown]
# 2. Filtre  `homeless` para los casos para los estados que comparten el desierto Mojave, asignelo a `mojave_homelessness`. Muestre el resultado.
#
# Los estados que comparten el [desierto Mojave](https://en.wikipedia.org/wiki/Mojave_Desert) son Arizona, California, Nevada y Utah

# %%
mojave_homelessness = homeless[(homeless["state"].isin(["Arizona","California","Nevada","Utah"]))]
mojave_homelessness
# Out:
#       region       state state code  individuals  individuals male  \
# 3   Mountain     Arizona         AZ         3304              2234
# 4    Pacific  California         CA        32910             21041
# 32  Mountain      Nevada         NV         2748              2034
# 43  Mountain        Utah         UT         1664              1072
#
#     individuals female  family_members  family_members male  \
# 3                 1046            2156                  840
# 4                11434           18519                 7495
# 32                 691             545                  183
# 43                 576             746                  285
#
#     family_members female  pop_state
# 3                    1313    7227450
# 4                   11009   39766650
# 32                    361    3145020
# 43                    459    3322389

# %% [markdown]
# ---
#
# ## Transformaciones
#
# Uno no está atascado únicamente con los datos que provienen del Dataset. Se puede crear nuevas columnas, lo que llamamos como transformaciones o también ingeniería de características.
#
# Se pueden crear columnas desde cero, pero también, tal como vimos de clase, es común obtenerlas de otras columnas.
#
# Siguiendo con el mismo DataFrame de los puntos anteriores (`homeless`),
#
# 1. Agregue una nueva columna a `homeless`, llamada `"total"`, que contenga la suma de `"individuals"` y `"family_members"`.

# %%
homeless["total"] = homeless["individuals"] + homeless["family_members"]

# %% [markdown]
# 2. Agregue otra columna a `homeless`, llamada `p_female`, que contiene la proporción de  personas sin hogar individuales en cada estado que son mujeres.

# %%
homeless["p_female"] = homeless["individuals female"] / homeless["individuals"]

homeless
# Out:
#                 region           state state code  individuals  \
# 0              Pacific          Alaska         AK         1295
# 1   East South Central         Alabama         AL         1165
# 2   West South Central        Arkansas         AR         1204
# 3             Mountain         Arizona         AZ         3304
# 4              Pacific      California         CA        32910
# 5             Mountain        Colorado         CO         5569
# 6          New England     Connecticut         CT         1504
# 7       South Atlantic        Delaware         DE          736
# 8       South Atlantic         Florida         FL         8412
# 9       South Atlantic         Georgia         GA         3111
# 10             Pacific          Hawaii         HI         1142
# 11  West North Central            Iowa         IA         1321
# 12            Mountain           Idaho         ID          591
# 13  East North Central        Illinois         IL         4065
# 14  East North Central         Indiana         IN         2765
# 15  West North Central          Kansas         KS         1113
# 16  East South Central        Kentucky         KY         1704
# 17  West South Central       Louisiana         LA         1150
# 18         New England   Massachusetts         MA         4278
# 19      South Atlantic        Maryland         MD         2764
# 20         New England           Maine         ME         1278
# 21  East North Central        Michigan         MI         3768
# 22  West North Central       Minnesota         MN         3716
# 23  West North Central        Missouri         MO         2359
# 24  East South Central     Mississippi         MS          271
# 25            Mountain         Montana         MT          744
# 26      South Atlantic  North Carolina         NC         3609
# 27  West North Central    North Dakota         ND          290
# 28  West North Central        Nebraska         NE         1280
# 29         New England   New Hampshire         NH          649
# 30        Mid-Atlantic      New Jersey         NJ         4821
# 31            Mountain      New Mexico         NM         1217
# 32            Mountain          Nevada         NV         2748
# 33        Mid-Atlantic        New York         NY        37793
# 34  East North Central            Ohio         OH         5020
# 35  West South Central        Oklahoma         OK         1674
# 36             Pacific          Oregon         OR         4167
# 37        Mid-Atlantic    Pennsylvania         PA         5450
# 38         New England    Rhode Island         RI          614
# 39      South Atlantic  South Carolina         SC         1552
# 40  West North Central    South Dakota         SD          517
# 41  East South Central       Tennessee         TN         2678
# 42  West South Central           Texas         TX         7518
# 43            Mountain            Utah         UT         1664
# 44      South Atlantic        Virginia         VA         3430
# 45         New England         Vermont         VT         1962
# 46             Pacific      Washington         WA         7013
# 47  East North Central       Wisconsin         WI         2275
# 48      South Atlantic   West Virginia         WV          682
# 49            Mountain         Wyoming         WY          247
#
#     individuals male  individuals female  family_members  family_members male  \
# 0                981                 310             502                  190
# 1                782                 377             461                  172
# 2                800                 403             266                   98
# 3               2234                1046            2156                  840
# 4              21041               11434           18519                 7495
# 5               3954                1587            2447                  960
# 6               1078                 418             661                  218
# 7                477                 257             843                  340
# 8               6001                2355            4981                 1774
# 9               2191                 894            2121                  669
# 10               703                 429            1348                  625
# 11               906                 412             685                  257
# 12               370                 219             426                  160
# 13              2632                1402            2868                 1060
# 14              1961                 793            1285                  471
# 15               759                 348             487                  194
# 16              1140                 558             583                  202
# 17               830                 312             463                  168
# 18              2908                1335            9666                 3806
# 19              1938                 812            1284                  470
# 20               779                 487             785                  320
# 21              2562                1184            2778                 1063
# 22              2400                1281            2745                 1049
# 23              1419                 918            1720                  650
# 24               159                 110              88                   27
# 25               511                 230             424                  167
# 26              2458                1140            2003                  774
# 27               196                  92             184                   64
# 28               908                 366             496                  196
# 29               434                 214             522                  201
# 30              3319                1489            2622                  968
# 31               779                 420             755                  329
# 32              2034                 691             545                  183
# 33             26504               10819           38258                14958
# 34              3408                1586            2742                 1026
# 35              1073                 588             657                  263
# 36              2764                1338            1011                  415
# 37              3772                1645            3914                 1455
# 38               440                 170             472                  176
# 39              1154                 397             490                  163
# 40               353                 161             300                  105
# 41              1885                 784             765                  290
# 42              5017                2460            3757                 1421
# 43              1072                 576             746                  285
# 44              2327                1083            1905                  746
# 45              1155                 793             629                  255
# 46              4594                2310            4498                 1842
# 47              1534                 723            1721                  683
# 48               428                 250             141                   60
# 49               108                 138             158                   57
#
#     family_members female  pop_state  total  p_female
# 0                     312     735707   1797  0.239382
# 1                     289    5048733   1626  0.323605
# 2                     168    3021085   1470  0.334718
# 3                    1313    7227450   5460  0.316586
# 4                   11009   39766650  51429  0.347432
# 5                    1482    5848166   8016  0.284970
# 6                     442    3609129   2165  0.277926
# 7                     503     999149   1579  0.349185
# 8                    3207   21811875  13393  0.279957
# 9                    1363   10814334   5232  0.287367
# 10                    719    1464768   2490  0.375657
# 11                    428    3204770   2006  0.311885
# 12                    265    1866258   1017  0.370558
# 13                   1808   12810696   6933  0.344895
# 14                    812    6815701   4050  0.286799
# 15                    292    2946356   1600  0.312668
# 16                    381    4522483   2287  0.327465
# 17                    295    4670195   1613  0.271304
# 18                   5858    7078146  13944  0.312062
# 19                    813    6217591   4048  0.293777
# 20                    465    1365759   2063  0.381064
# 21                   1715   10096700   6546  0.314225
# 22                   1691    5746751   6461  0.344726
# 23                   1070    6171512   4079  0.389148
# 24                     61    2960677    359  0.405904
# 25                    257    1093706   1168  0.309140
# 26                   1229   10529778   5612  0.315877
# 27                    120     789744    474  0.317241
# 28                    299    1975020   1776  0.285938
# 29                    321    1383635   1171  0.329738
# 30                   1653    9338704   7443  0.308857
# 31                    425    2123356   1972  0.345111
# 32                    361    3145020   3293  0.251456
# 33                  23294   20283564  76051  0.286270
# 34                   1714   11825742   7762  0.315936
# 35                    394    3980153   2331  0.351254
# 36                    592    4277874   5178  0.321094
# 37                   2454   13032732   9364  0.301835
# 38                    295    1101860   1086  0.276873
# 39                    327    5167731   2042  0.255799
# 40                    195     893916    817  0.311412
# 41                    475    6967314   3443  0.292756
# 42                   2335   29545499  11275  0.327215
# 43                    459    3322389   2410  0.346154
# 44                   1158    8694430   5335  0.315743
# 45                    374     644811   2591  0.404179
# 46                   2647    7803355  11511  0.329388
# 47                   1036    5914391   3996  0.317802
# 48                     81    1787788    823  0.366569
# 49                    101     578173    405  0.558704

# %% [markdown]
# 3. Agregue una columna a `homeless`, llamada `"family_members non binary"` con el número de personas sin hogar con familia que no se definen como male o female.

# %%
homeless["family_members non binary"] = homeless["family_members"] - homeless["family_members female"] - homeless["family_members male"]
homeless["family_members non binary"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4     15
# 5      5
# 6      1
# 7      0
# 8      0
# 9     89
# 10     4
# 11     0
# 12     1
# 13     0
# 14     2
# 15     1
# 16     0
# 17     0
# 18     2
# 19     1
# 20     0
# 21     0
# 22     5
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     1
# 29     0
# 30     1
# 31     1
# 32     1
# 33     6
# 34     2
# 35     0
# 36     4
# 37     5
# 38     1
# 39     0
# 40     0
# 41     0
# 42     1
# 43     2
# 44     1
# 45     0
# 46     9
# 47     2
# 48     0
# 49     0
# Name: family_members non binary, dtype: int64

# %% [markdown]
# ---
#
# ## Combinando lo aprendido
#
# Usando las herramientas que se han usado hasta ahora, responda la siguiente pregunta
#
# ¿Qué estado tiene el mayor número de personas sin hogar individuales por cada 10.000 personas en el estado?
#
# Pistas:
#
# - Agregue a `homeless` una columna llamada `"indiv_per_10k"` conteniendo el número de personas sin hogar individuales dividido la población del estado. Multiplique esta division por `10000`.
# - Filtre las filas en donde `"indiv_per_10k"` es mayor a `10`, asignalo a `homelessness_high`.
# - Ordene `homelessness_high` de forma descendente usando la columna `"indiv_per_10k"`. asignalo a `homelessness_high_sorted`.
# - Seleccione únicamente la columna `state` e `indiv_per_10k` de `homelessness_high_sorted` y asignalo a `result`.
# - Imprima `result`.

# %%
homeless["indiv_per_10k"] = (homeless["individuals"] / homeless["total"]) * 10000

homelessness_high = homeless[homeless["indiv_per_10k"] > 10]

homelessness_high_sorted = homelessness_high.sort_values("indiv_per_10k", ascending=False)

result = homelessness_high_sorted[["state", "indiv_per_10k"]]

# Mostramos el resultado
result
# Out:
#              state  indiv_per_10k
# 32          Nevada    8344.974188
# 48   West Virginia    8286.755772
# 2         Arkansas    8190.476190
# 36          Oregon    8047.508691
# 41       Tennessee    7778.100494
# 39  South Carolina    7600.391773
# 45         Vermont    7572.365882
# 24     Mississippi    7548.746518
# 16        Kentucky    7450.808920
# 28        Nebraska    7207.207207
# 0           Alaska    7206.455203
# 35        Oklahoma    7181.467181
# 1          Alabama    7164.821648
# 17       Louisiana    7129.572226
# 15          Kansas    6956.250000
# 5         Colorado    6947.355289
# 6      Connecticut    6946.882217
# 43            Utah    6904.564315
# 19        Maryland    6828.063241
# 14         Indiana    6827.160494
# 42           Texas    6667.849224
# 11            Iowa    6585.244267
# 30      New Jersey    6477.226925
# 34            Ohio    6467.405308
# 26  North Carolina    6430.862438
# 44        Virginia    6429.240862
# 4       California    6399.113341
# 25         Montana    6369.863014
# 40    South Dakota    6328.029376
# 8          Florida    6280.893004
# 20           Maine    6194.861852
# 31      New Mexico    6171.399594
# 27    North Dakota    6118.143460
# 49         Wyoming    6098.765432
# 46      Washington    6092.433325
# 3          Arizona    6051.282051
# 9          Georgia    5946.100917
# 13        Illinois    5863.262657
# 37    Pennsylvania    5820.162324
# 12           Idaho    5811.209440
# 23        Missouri    5783.280216
# 21        Michigan    5756.186984
# 22       Minnesota    5751.431667
# 47       Wisconsin    5693.193193
# 38    Rhode Island    5653.775322
# 29   New Hampshire    5542.271563
# 33        New York    4969.428410
# 7         Delaware    4661.177961
# 10          Hawaii    4586.345382
# 18   Massachusetts    3067.986231
